# %% [markdown]
# ![image.png](attachment:ded69657-9b18-4721-ac19-19286a658ca5.png)

# %% [markdown]
# ![image.png](attachment:7ec56def-7374-4664-bafc-91b636afae07.png)

# %% [markdown]
# Codes below

# %%
#1
name = 'Shubham'
print(name)
# Out:
# Shubham

# %%
#2
str = "Hello World"
len(str)
# Out:
# 11

# %%
#3
stri = 'Python Programming'
stri[0:3]
# Out:
# 'Pyt'

# %%
#4
a = 'hello'
a.upper()
# Out:
# 'HELLO'

# %%
#5
strin = 'I like apple'
strin.replace('apple','orange')
# Out:
# 'I like orange'

# %%
#6
lis = [1,2,3,4,5]
lis
# Out:
# [1, 2, 3, 4, 5]

# %%
#7
l = [1,2,3,4]
l.append(10)
l
# Out:
# [1, 2, 3, 4, 10]

# %%
#8
l=[1,2,3,4,5]
l.remove(3)
l
# Out:
# [1, 2, 4, 5]

# %%
#9
l = ['a','b','c','d']
l[1]
# Out:
# 'b'

# %%
#10
l = [10,20,30,40,50]
l[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
#11
t =(100,200,300)
print(t)
# Out:
# (100, 200, 300)

# %%
#12
t=('red','green','blue','yellow')
t[-2]
# Out:
# 'blue'

# %%
#13
t = (10,20,5,15)
min(t)
# Out:
# 5

# %%
#14
t=('dog','cat','rabbit')
t.index('cat')
# Out:
# 1

# %%
#15
t = ('orange','apple','banana')
'kiwi' in t
# Out:
# False

# %%
#16
s={'a','b','c'}
s
# Out:
# {'a', 'b', 'c'}

# %%
#17
s={1,2,3,4,5}
s.clear()
s
# Out:
# set()

# %%
#18
s={1,2,3,4}
s.remove(4)
s
# Out:
# {1, 2, 3}

# %%
#19
a={1,2,3}
b={3,4,5}
a|b
# Out:
# {1, 2, 3, 4, 5}

# %%
#20
a={1,2,3}
b={3,4,5}
a&b
# Out:
# {3}

# %%
#21;
dic={'name':'Shubham',"age":23,'city':'LA'}
dic
# Out:
# {'name': 'Shubham', 'age': 23, 'city': 'LA'}

# %%
#22
dic['country']='USA'
dic
# Out:
# {'name': 'Shubham', 'age': 23, 'city': 'LA', 'country': 'USA'}

# %%
#23
dic['name']
# Out:
# 'Shubham'

# %%
#24
dic.pop('age') #error because once popped
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_57/4252042457.py in <cell line: 0>()
#       1 #24
# ----> 2 dic.pop('age')
#       3 dic
#
# KeyError: 'age'

# %%
dic
# Out:
# {'name': 'Shubham', 'city': 'LA', 'country': 'USA'}

# %%
#25
'city' in dic
# Out:
# True

# %%
#26
l = [2,3,3,4,('a','b'),{'name':'Shubh','Age':23}]
print(l)
# Out:
# [2, 3, 3, 4, ('a', 'b'), {'name': 'Shubh', 'Age': 23}]

# %%
#27
l=[10,7,99,33,27]
sorted(l)
# Out:
# [7, 10, 27, 33, 99]

# %%
#28
l=['a','b','c','d','e','f']
l[3]
# Out:
# 'd'

# %%
#29
d1={'Name':'Shubh','Age':23}
d2={'City':'LA','Country':'USA'}
d1.update(d2)
print(d1)
# Out:
# {'Name': 'Shubh', 'Age': 23, 'City': 'LA', 'Country': 'USA'}

# %%
#30
l=['Shubh','Mann','Us','Krishna']
set(l)
# Out:
# {'Krishna', 'Mann', 'Shubh', 'Us'}
